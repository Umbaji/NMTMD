# %%
book = []

with open("out.txt", "r" ,encoding = "utf-8") as dataset :
    book = dataset.read()

#book_0 = str(book_0)

#print(book)

book_content = book.split("(Luka 3:23-38)")[1]

book_content = book_content.split('\n')[1]

book_content = book_content.split('\\n')

print(book_content)
# Out:
# ["['Marc', '2 janvier 2016 admin Aucun commentaire Bible, évangile, ewe, Togo', 'NYANYUI LA ABE ALE SI MARKO ŊLɔE ENE", 'Kpɔkplɔyiɖeme :', 'Marko nye ɖekakpui aɖe si nye Petro, ame si nye Yesu ƒe nusrɔ̃lawo dometɔ ɖeka la', 'xɔlɔ̃. Eŋlɔ nu siwo dzi Petro ɖo ŋkui tso Yesu ŋuti nɛ la ɖe agbalẽa me. Meŋlɔ nya', 'aɖeke tso Yesu ƒe ƒome, dzidzi kple ɖevimenɔnɔ ŋu o, eye mete gbe ɖe Yesu ƒe', 'nyagbɔgblɔwo dzi tututu o; ke boŋ ete gbe ɖe Yesu ƒe nuwɔwɔwo dzi. Eŋlɔ nya', 'geɖewo tso Yudatɔwo ƒe kɔnyinyiwo ŋu. Esia fia be eŋlɔ agbalẽa na ame siwo', 'menye Yudatɔwo o.', 'Emenyawo 1. Yesu dze eƒe dɔwɔwɔ gɔme, 1:1-13', '2. Yesu ƒe dɔwɔwɔ le Galilea zi gbãtɔ, 1:14-3:6', '3. Yesu ƒe dɔwɔwɔ le Galilea zi evelia, 3:7-7:23', '4. Yesu ƒe dɔwɔwɔ le Galilea zi etɔ̃lia, 7 :24-9 :50', '5. Yesu tso Galilea yi Yerusalem, 10 :1-52', '6. Yesu ƒe dɔwɔwɔ le Yerusalem. eƒe fukpekpe kple ku, 11:1-16:8', '7. Yesu ƒe tsitretsitsi kple ɖokui ɖeɖefia, 16:9-20', 'Yohanes ɖe gbeƒã Kristo', 'Chapter 1', '(Mateo 3:1-12;
# ...
